# %%
import pandas as pd
import numpy as no 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wafer.csv')

# %%
df.head()
# Out:
#   Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-201   3088.73   2378.95  2185.9333  1659.6962    1.6290       100
# 1  Wafer-202   2940.65       NaN  2214.0556  1150.7775    1.3772       100
# 2  Wafer-203   2948.42   2444.55  2204.9223  1787.6757    1.5138       100
# 3  Wafer-204   2958.39   2478.99  2231.9556  1185.0959    1.0208       100
# 4  Wafer-205   3025.01   2604.26  2177.3222  1089.3655    1.3101       100
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   98.6822    0.1227    1.3731  ...         NaN      0.4990      0.0130
# 1  102.9389    0.1205    1.4978  ...     83.1192      0.5038      0.0188
# 2  100.4322    0.1216    1.3906  ...    272.3477      0.5006      0.0164
# 3  102.5344    0.1192    1.4881  ...         NaN      0.5024      0.0151
# 4  101.1478    0.1216    1.4476  ...         NaN      0.4977      0.0184
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=592)

# %%
df.dtypes
# Out:
# Unnamed: 0     object
# Sensor-1      float64
# Sensor-2      float64
# Sensor-3      float64
# Sensor-4      float64
#                ...
# Sensor-587    float64
# Sensor-588    float64
# Sensor-589    float64
# Sensor-590    float64
# Good/Bad        int64
# Length: 592, dtype: object

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# Sensor-1      0
# Sensor-2      2
# Sensor-3      0
# Sensor-4      0
#              ..
# Sensor-587    0
# Sensor-588    0
# Sensor-589    0
# Sensor-590    0
# Good/Bad      0
# Length: 592, dtype: int64

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   Unnamed: 0
# 0  Wafer-201
# 1  Wafer-202
# 2  Wafer-203
# 3  Wafer-204
# 4  Wafer-205

# %%
num_df = df.select_dtypes(include=['int64','float64']).copy()
num_df.head()
# Out:
#    Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
# 0   3088.73   2378.95  2185.9333  1659.6962    1.6290       100   98.6822
# 1   2940.65       NaN  2214.0556  1150.7775    1.3772       100  102.9389
# 2   2948.42   2444.55  2204.9223  1787.6757    1.5138       100  100.4322
# 3   2958.39   2478.99  2231.9556  1185.0959    1.0208       100  102.5344
# 4   3025.01   2604.26  2177.3222  1089.3655    1.3101       100  101.1478
#
#    Sensor-8  Sensor-9  Sensor-10  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0    0.1227    1.3731     0.0056  ...         NaN      0.4990      0.0130
# 1    0.1205    1.4978     0.0221  ...     83.1192      0.5038      0.0188
# 2    0.1216    1.3906    -0.0018  ...    272.3477      0.5006      0.0164
# 3    0.1192    1.4881    -0.0054  ...         NaN      0.5024      0.0151
# 4    0.1216    1.4476    -0.0234  ...         NaN      0.4977      0.0184
#
# ...

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
obj_df = obj_df.apply(lb_make.fit_transform)

# %%
new_df = pd.concat([obj_df, num_df], axis=1)
new_df.head()
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0           0   3088.73   2378.95  2185.9333  1659.6962    1.6290       100
# 1           1   2940.65       NaN  2214.0556  1150.7775    1.3772       100
# 2           2   2948.42   2444.55  2204.9223  1787.6757    1.5138       100
# 3           3   2958.39   2478.99  2231.9556  1185.0959    1.0208       100
# 4           4   3025.01   2604.26  2177.3222  1089.3655    1.3101       100
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   98.6822    0.1227    1.3731  ...         NaN      0.4990      0.0130
# 1  102.9389    0.1205    1.4978  ...     83.1192      0.5038      0.0188
# 2  100.4322    0.1216    1.3906  ...    272.3477      0.5006      0.0164
# 3  102.5344    0.1192    1.4881  ...         NaN      0.5024      0.0151
# 4  101.1478    0.1216    1.4476  ...         NaN      0.4977      0.0184
#
# ...

# %%
#fill na with mean
mean_new_df = new_df.fillna(new_df.mean())

# %%
mean_new_df.isna().sum()
# Out:
# Unnamed: 0    0
# Sensor-1      0
# Sensor-2      0
# Sensor-3      0
# Sensor-4      0
#              ..
# Sensor-587    0
# Sensor-588    0
# Sensor-589    0
# Sensor-590    0
# Good/Bad      0
# Length: 592, dtype: int64

# %%
mean_new_df.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=592)

# %%
#forward feature selection
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression

X = mean_new_df.drop('Good/Bad', axis=1)
y = mean_new_df['Good/Bad']

# %%
X.head()
# Out:
#    Unnamed: 0  Sensor-1     Sensor-2   Sensor-3   Sensor-4  Sensor-5  \
# 0           0   3088.73  2378.950000  2185.9333  1659.6962    1.6290
# 1           1   2940.65  2494.334388  2214.0556  1150.7775    1.3772
# 2           2   2948.42  2444.550000  2204.9223  1787.6757    1.5138
# 3           3   2958.39  2478.990000  2231.9556  1185.0959    1.0208
# 4           4   3025.01  2604.260000  2177.3222  1089.3655    1.3101
#
#    Sensor-6  Sensor-7  Sensor-8  Sensor-9  ...  Sensor-581  Sensor-582  \
# 0       100   98.6822    0.1227    1.3731  ...    0.004652  104.105022
# 1       100  102.9389    0.1205    1.4978  ...    0.003100   83.119200
# 2       100  100.4322    0.1216    1.3906  ...    0.003000  272.347700
# 3       100  102.5344    0.1192    1.4881  ...    0.004652  104.105022
# 4       100  101.1478    0.1216    1.4476  ...    0.004652  104.105022
#
#    Sensor-583  Sensor-584  Sensor-585  Sensor-586  Sensor-587  Sensor-588  \
# ...

# %%
y.head()
# Out:
# 0   -1
# 1    1
# 2   -1
# 3   -1
# 4   -1
# Name: Good/Bad, dtype: int64

# %%
print(X.shape), print(y.shape)
# Out:
# (100, 591)
# (100,)
# (None, None)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
print(X_train.shape), print(X_test.shape), print(y_train.shape), print(y_test.shape)
# Out:
# (70, 591)
# (30, 591)
# (70,)
# (30,)
# (None, None, None, None)

# %%
sfs1 = sfs(LinearRegression(), k_features=5, forward=True, scoring='r2', cv=5)
sfs1 = sfs1.fit(X_train, y_train)
# Out:
# /home/feather/Documents/ML/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# /home/feather/Documents/ML/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# /home/feather/Documents/ML/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# /home/feather/Documents/ML/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# ...
